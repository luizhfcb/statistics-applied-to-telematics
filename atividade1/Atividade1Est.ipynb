# %% [markdown]
# Questão 1:
#
# Listas sao basicamente uma sequencia de valores armazenados, Já os ndarrays sao bastante parecidos com as listas, porem possui algumas funcionalidades a mais, sendo a vetoriazação a funcionalidade com mais destaque. Sobre os dicionarios, a grande diferença é na forma em que acessamos os dados, nesse, os dados sao acessados atraves de uma chave que foi associada a ela, enquanto nas listas voce acessa por meio de índice.
# Série Panda são unidimensionais ndarrays com rótulos de eixo, que permitem armazenar valores e são uma das estruturas de dados internas de numpy.

# %% [markdown]
# Questão 2:

# %%
import pandas as pd
import numpy as np

ser = pd.DataFrame(np.random.randint(1,10,size=(7,5)), columns=list('12345'))
ser
# Out:
#    1  2  3  4  5
# 0  7  5  8  6  8
# 1  2  2  2  8  1
# 2  9  9  2  2  2
# 3  5  2  2  1  6
# 4  2  4  4  6  5
# 5  1  8  4  2  7
# 6  8  4  1  3  8

# %% [markdown]
# Questao 3:

# %%
q3 = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')
crim = pd.DataFrame(q3['crim'])
medv = pd.DataFrame(q3['medv'])
crim
# Out:
#         crim
# 0    0.00632
# 1    0.02731
# 2    0.02729
# 3    0.03237
# 4    0.06905
# ..       ...
# 501  0.06263
# 502  0.04527
# 503  0.06076
# 504  0.10959
# 505  0.04741
#
# [506 rows x 1 columns]

# %% [markdown]
# Questao 4:

# %%
q4 = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
q4.rename(columns={'Type':'CarType'}, inplace =True)
q4.columns= q4.columns.str.replace('.','_')
q4
# Out:
# <ipython-input-51-a2dea98f0182>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   q4.columns= q4.columns.str.replace('.','_')
#    Manufacturer    Model  CarType  Min_Price  Price  Max_Price  MPG_city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1           NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# ...

# %% [markdown]
# Questao 5:

# %%
qtdfal = q4.isnull().sum()
qtdfal
# Out:
# Manufacturer           4
# Model                  1
# Type                   3
# Min.Price              7
# Price                  2
# Max.Price              5
# MPG.city               9
# MPG.highway            2
# AirBags                6
# DriveTrain             7
# Cylinders              5
# EngineSize             2
# Horsepower             7
# RPM                    3
# Rev.per.mile           6
# Man.trans.avail        5
# Fuel.tank.capacity     8
# Passengers             2
# Length                 4
# Wheelbase              1
# Width                  6
# Turn.circle            5
# Rear.seat.room         4
# Luggage.room          19
# Weight                 7
# Origin                 5
# Make                   3
# dtype: int64

# %% [markdown]
# Questao 6:

# %%
maiorv = q4.isnull().max()
maiorv
# Out:
# Manufacturer          True
# Model                 True
# CarType               True
# Min_Price             True
# Price                 True
# Max_Price             True
# MPG_city              True
# MPG_highway           True
# AirBags               True
# DriveTrain            True
# Cylinders             True
# EngineSize            True
# Horsepower            True
# RPM                   True
# Rev_per_mile          True
# Man_trans_avail       True
# Fuel_tank_capacity    True
# Passengers            True
# Length                True
# Wheelbase             True
# Width                 True
# Turn_circle           True
# Rear_seat_room        True
# Luggage_room          True
# Weight                True
# Origin                True
# Make                  True
# dtype: bool

# %% [markdown]
# Questao 7:

# %%
df = pd.DataFrame(np.arange(20).reshape(-1,5), columns=list('abcde'))
df
# Out:
#     a   b   c   d   e
# 0   0   1   2   3   4
# 1   5   6   7   8   9
# 2  10  11  12  13  14
# 3  15  16  17  18  19

# %%
ca = pd.DataFrame(df['a'])
ca
# Out:
#     a
# 0   0
# 1   5
# 2  10
# 3  15

# %% [markdown]
# Questao 8: Letra A

# %%
df = df[['c','b','a','d','e']]
df
# Out:
#     c   b   a   d   e
# 0   2   1   0   3   4
# 1   7   6   5   8   9
# 2  12  11  10  13  14
# 3  17  16  15  18  19

# %% [markdown]
# Questao 8 letra B:

# %%
df.insert(0, 'newColMean', df.mean(1))

# %% [markdown]
# Questao 8 letra C:

# %%
df.sort_values(by=0, axis=1,ascending= False)
# Out:
#     e   d   c   b   a
# 0   4   3   2   1   0
# 1   9   8   7   6   5
# 2  14  13  12  11  10
# 3  19  18  17  16  15

# %% [markdown]
# Questao 9:

# %%
q9 = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
#q9 = pd.DataFrame(size=(10,10))
df.columns.tolist()
df.arrows.tolist()
# Out:
#   Manufacturer       Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura     Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN      Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi          90  Compact       25.9   29.1       32.3      20.0
# 3         Audi         100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW        535i  Midsize        NaN   30.0        NaN      22.0
# 5        Buick     Century  Midsize       14.2   15.7       17.3      22.0
# 6        Buick     LeSabre    Large       19.9   20.8        NaN      19.0
# 7        Buick  Roadmaster    Large       22.6   23.7       24.9      16.0
# 8        Buick     Riviera  Midsize       26.3   26.3       26.3      19.0
# 9     Cadillac     DeVille    Large       33.0   34.7       36.3      16.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# ...
